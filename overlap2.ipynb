# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
file_path = "data/overlap_df.csv"
df = pd.read_csv(file_path, index_col=0)

# Extract keyword names
keywords = df.index.tolist()

# %%
print(len(keywords))
# Out:
# 29

# %%
LAMBDA = 0.7  
ALPHA = 1.0 
Beta = 4.0
overlap_matrix = df.to_numpy()
print(overlap_matrix)
# Out:
# [[ 0 21  9 20 24  5 13  0  2  2  5  7  3  4  4  2 10  6  6  1  1  3  3  1
#    5 12  7  1 16]
#  [21  0  7 17 21  3 11  1  3  2  3  6  3  4  4  2  7  7  5  1  1  2  2  1
#    5  9  5  2 12]
#  [ 9  7  0 10 11  3 13  1  2  4  2  6  3  4  5  1 25  8  3  2  3  6  2  2
#    1  8  6  4 12]
#  [20 17 10  0 22  7 16  4  4  3  7 10  8  4  9  4 13 10  7  3  3  4  3  3
#    7 15 12  4 21]
#  [24 21 11 22  0  7 18  2  4  5  6  9  4  5  6  4 12  9  7  4  3  6  5  4
#    5 13 10  3 17]
#  [ 5  3  3  7  7  0  7  4  8  4 16 28 19 24 29 17  5 13  7  2  7  2  5  5
#   11 22 23  4 10]
#  [13 11 13 16 18  7  0  4  3  4  6 12  7  8  8  4 14 10  5  2  5  6  3  3
#    4 16 13  4 17]
#  [ 0  1  1  4  2  4  4  0  5  5  0  3  3  3  5  3  3  2  5  4  6  4  5  5
#    1  3  5 10  4]
#  [ 2  3  2  4  4  8  3  5  0 21  2  6  3  4  8  8  2 11 27 16 17 15 19 19
#    4  7 11  1  4]
#  [ 2  2  4  3  5  4  4  5 21  0  2  3  1  2  5  2  4  4 17 26 18 22 20 25
#    2  4  4  1  4]
#  [ 5  3  2  7  6 16  6  0  2  2  0 22 15 18 20 12  3  7  4  0  3  0  1  0
#   13 12 14  1  8]
#  [ 7  6  6 10  9 28 12  3  6  3 22  0 17 28 30 16  8 15  6  1  6  1  3  2
#   11 23 22  2 14]
#  [ 3  3  3  8  4 19  7  3  3  1 15 17  0 19 24 12  4 10  4  0  5  0  2  0
#   15 13 19  3  9]
#  [ 4  4  4  4  5 24  8  3  4  2 18 28 19  0 28 14  6 11  5  1  5  1  1  1
#   11 19 17  4  8]
#  [ 4  4  5  9  6 29  8  5  8  5 20 30 24 28  0 19  6 13  8  4 10  4  5  5
#    9 19 24  3 10]
#  [ 2  2  1  4  4 17  4  3  8  2 12 16 12 14 19  0  4 12  5  1  5  1  4  2
#    8 11 20  3  6]
#  [10  7 25 13 12  5 14  3  2  4  3  8  4  6  6  4  0  9  3  2  4  5  3  2
#    2 11  9  4 16]
#  [ 6  7  8 10  9 13 10  2 11  4  7 15 10 11 13 12  9  0 10  3  8  3 10  4
#    7 15 26  4 16]
#  [ 6  5  3  7  7  7  5  5 27 17  4  6  4  5  8  5  3 10  0 16 18 17 18 20
#    5  7  9  3  7]
#  [ 1  1  2  3  4  2  2  4 16 26  0  1  0  1  4  1  2  3 16  0 15 30 16 26
#    1  2  3  1  3]
#  [ 1  1  3  3  3  7  5  6 17 18  3  6  5  5 10  5  4  8 18 15  0 14 17 18
#    4  7  8  3  3]
#  [ 3  2  6  4  6  2  6  4 15 22  0  1  0  1  4  1  5  3 17 30 14  0 14 24
#    1  5  3  1  3]
#  [ 3  2  2  3  5  5  3  5 19 20  1  3  2  1  5  4  3 10 18 16 17 14  0 17
#    3  3  9  1  5]
#  [ 1  1  2  3  4  5  3  5 19 25  0  2  0  1  5  2  2  4 20 26 18 24 17  0
#    1  4  3  2  3]
#  [ 5  5  1  7  5 11  4  1  4  2 13 11 15 11  9  8  2  7  5  1  4  1  3  1
#    0  8 10  1  5]
#  [12  9  8 15 13 22 16  3  7  4 12 23 13 19 19 11 11 15  7  2  7  5  3  4
#    8  0 21  5 15]
#  [ 7  5  6 12 10 23 13  5 11  4 14 22 19 17 24 20  9 26  9  3  8  3  9  3
#   10 21  0  5 21]
#  [ 1  2  4  4  3  4  4 10  1  1  1  2  3  4  3  3  4  4  3  1  3  1  1  2
#    1  5  5  0  4]
#  [16 12 12 21 17 10 17  4  4  4  8 14  9  8 10  6 16 16  7  3  3  3  5  3
#    5 15 21  4  0]]

# %%
S = np.sum(overlap_matrix, axis=1)

# %%
N = len(keywords)
D = np.zeros(N)
for i in range(N):
    D[i] = (1 / N) * np.sum(overlap_matrix[i] * S)

# %%
A = S - LAMBDA * D

# %%
# Normalize Scores
min_A, max_A = np.min(A), np.max(A)
N_i = (A - min_A) / (max_A - min_A)

# %%
W = np.round(ALPHA + (Beta) * N_i).astype(int)

# %%
df_result = pd.DataFrame({
    "Keyword": keywords,
    "Raw Score (S)": S,
    "Dependency Factor (D)": np.round(D, 2),
    "Adjusted Score (A)": np.round(A, 2),
    "Normalized Score (N_i)": np.round(N_i, 2),
    "Final Search Weight (W)": W
})

# %%
df_result = df_result.sort_values(by="Final Search Weight (W)", ascending=False)

# %%
from IPython.display import display
display(df_result)
# Out:
#                                         Keyword  Raw Score (S)  \
# 27                               همراه پلاس ملت             84
# 7                       دانلود مستقیم بانک پلاس            100
# 2                                      بانک ملت            163
# 19                                      مگابانک            186
# 21                                  مگابانک ملت            197
# 24       نصب همراه بانک ملت بدون مراجعه به شعبه            160
# 1                             اینترنتی ملت بانک            167
# 0                              اینترنت بانک ملت            193
# 23                                مگابانک همراه            202
# 18                         مگا بانک ملت نسخه وب            254
# 22                          مگابانک نسخه تحت وب            199
# 16                                     ملت بانک            196
# 15               دانلود همراه بانک ملت نسخه ios            202
# 10  دانلود نسخه جدید همراه بانک ملت با رمز پویا            202
# 12            دانلود همراه بانک ملت از گوگل پلی            225
# 9                                دانلود مگابانک            216
# 8                دانلود مگا بانک ملت برای ایفون            236
# 6                                خدمات بانک ملت            236
# 4                         بانکداری اینترنتی ملت            246
# 3                        بانک ملت اینترنتی جدید            250
# 20                           مگابانک آخرین نسخه            217
# 28                                  وب بانک ملت            273
# 17                              ملت نسخه تحت وب            263
# 13                دانلود همراه بانک ملت اندروید            259
# 11                        دانلود همراه بانک ملت            317
# 25                               همراه بانک ملت            309
# 26                   همراه بانک ملت نسخه تحت وب            339
# 5                      بروزرسانی همراه بانک ملت            297
# 14         دانلود همراه بانک ملت با لینک مستقیم            324
#
#     Dependency Factor (D)  Adjusted Score (A)  Normalized Score (N_i)  \
# 27                 667.34             -383.14                    1.00
# 7                  785.52             -449.86                    0.95
# 2                 1324.03             -763.82                    0.70
# 19                1410.21             -801.14                    0.67
# 21                1486.45             -843.51                    0.64
# 24                1391.83             -814.28                    0.66
# 1                 1374.34             -795.04                    0.68
# 0                 1591.83             -921.28                    0.58
# 23                1541.07             -876.75                    0.62
# 18                1983.17            -1134.22                    0.42
# 22                1571.03             -900.72                    0.60
# 16                1585.45             -913.81                    0.59
# 15                1816.72            -1069.71                    0.47
# 10                1831.10            -1079.77                    0.46
# 12                2003.17            -1177.22                    0.38
# 9                 1634.83             -928.38                    0.58
# 8                 1883.86            -1082.70                    0.46
# 6                 1946.93            -1126.85                    0.42
# 4                 1964.55            -1129.19                    0.42
# 3                 2026.90            -1168.83                    0.39
# 20                1720.24             -987.17                    0.53
# 28                2265.03            -1312.52                    0.28
# 17                2254.83            -1315.38                    0.28
# 13                2304.24            -1353.97                    0.25
# 11                2760.97            -1615.68                    0.04
# 25                2627.93            -1530.55                    0.11
# 26                2868.66            -1669.06                    0.00
# 5                 2605.10            -1526.57                    0.11
# 14                2784.59            -1625.21                    0.03
#
#     Final Search Weight (W)
# 27                        5
# 7                         5
# 2                         4
# 19                        4
# 21                        4
# 24                        4
# 1                         4
# 0                         3
# 23                        3
# 18                        3
# 22                        3
# 16                        3
# 15                        3
# 10                        3
# 12                        3
# 9                         3
# 8                         3
# 6                         3
# 4                         3
# 3                         3
# 20                        3
# 28                        2
# 17                        2
# 13                        2
# 11                        1
# 25                        1
# 26                        1
# 5                         1
# 14                        1

# %%
fixed_keyword = "دانلود همراه بانک ملت با لینک مستقیم"
fixed_W = 5  # Desired fixed search weight

if fixed_keyword in df_result["Keyword"].values:
    # Set fixed W value for the specific keyword
    df_result.loc[df_result["Keyword"] == fixed_keyword, "Final Search Weight (W)"] = fixed_W
    
    # Reduce W for keywords highly related to the fixed keyword
    keyword_index = keywords.index(fixed_keyword)
    related_scores = overlap_matrix[keyword_index]  # Get overlap values for the fixed keyword
    # threshold = np.percentile(related_scores, 75)  
    threshold = 19
    # Reduce W for highly related keywords
    for i, rel_score in enumerate(related_scores):
        if i != keyword_index and rel_score > threshold:  # High relation threshold
            df_result.loc[df_result["Keyword"] == keywords[i], "Final Search Weight (W)"] = max(1, fixed_W - 3)

# Ensure W values remain as integers
df_result["Final Search Weight (W)"] = df_result["Final Search Weight (W)"].astype(int)

# Sort by Final Search Weight (Descending)
df_result = df_result.sort_values(by="Final Search Weight (W)", ascending=False)

# Display the updated results
display(df_result)
# Out:
#                                         Keyword  Raw Score (S)  \
# 27                               همراه پلاس ملت             84
# 7                       دانلود مستقیم بانک پلاس            100
# 14         دانلود همراه بانک ملت با لینک مستقیم            324
# 19                                      مگابانک            186
# 2                                      بانک ملت            163
# 24       نصب همراه بانک ملت بدون مراجعه به شعبه            160
# 1                             اینترنتی ملت بانک            167
# 21                                  مگابانک ملت            197
# 20                           مگابانک آخرین نسخه            217
# 3                        بانک ملت اینترنتی جدید            250
# 4                         بانکداری اینترنتی ملت            246
# 6                                خدمات بانک ملت            236
# 9                                دانلود مگابانک            216
# 8                دانلود مگا بانک ملت برای ایفون            236
# 15               دانلود همراه بانک ملت نسخه ios            202
# 16                                     ملت بانک            196
# 22                          مگابانک نسخه تحت وب            199
# 18                         مگا بانک ملت نسخه وب            254
# 23                                مگابانک همراه            202
# 0                              اینترنت بانک ملت            193
# 10  دانلود نسخه جدید همراه بانک ملت با رمز پویا            202
# 28                                  وب بانک ملت            273
# 17                              ملت نسخه تحت وب            263
# 13                دانلود همراه بانک ملت اندروید            259
# 11                        دانلود همراه بانک ملت            317
# 26                   همراه بانک ملت نسخه تحت وب            339
# 5                      بروزرسانی همراه بانک ملت            297
# 12            دانلود همراه بانک ملت از گوگل پلی            225
# 25                               همراه بانک ملت            309
#
#     Dependency Factor (D)  Adjusted Score (A)  Normalized Score (N_i)  \
# 27                 667.34             -383.14                    1.00
# 7                  785.52             -449.86                    0.95
# 14                2784.59            -1625.21                    0.03
# 19                1410.21             -801.14                    0.67
# 2                 1324.03             -763.82                    0.70
# 24                1391.83             -814.28                    0.66
# 1                 1374.34             -795.04                    0.68
# 21                1486.45             -843.51                    0.64
# 20                1720.24             -987.17                    0.53
# 3                 2026.90            -1168.83                    0.39
# 4                 1964.55            -1129.19                    0.42
# 6                 1946.93            -1126.85                    0.42
# 9                 1634.83             -928.38                    0.58
# 8                 1883.86            -1082.70                    0.46
# 15                1816.72            -1069.71                    0.47
# 16                1585.45             -913.81                    0.59
# 22                1571.03             -900.72                    0.60
# 18                1983.17            -1134.22                    0.42
# 23                1541.07             -876.75                    0.62
# 0                 1591.83             -921.28                    0.58
# 10                1831.10            -1079.77                    0.46
# 28                2265.03            -1312.52                    0.28
# 17                2254.83            -1315.38                    0.28
# 13                2304.24            -1353.97                    0.25
# 11                2760.97            -1615.68                    0.04
# 26                2868.66            -1669.06                    0.00
# 5                 2605.10            -1526.57                    0.11
# 12                2003.17            -1177.22                    0.38
# 25                2627.93            -1530.55                    0.11
#
#     Final Search Weight (W)
# 27                        5
# 7                         5
# 14                        5
# 19                        4
# 2                         4
# 24                        4
# 1                         4
# 21                        4
# 20                        3
# 3                         3
# 4                         3
# 6                         3
# 9                         3
# 8                         3
# 15                        3
# 16                        3
# 22                        3
# 18                        3
# 23                        3
# 0                         3
# 10                        2
# 28                        2
# 17                        2
# 13                        2
# 11                        2
# 26                        2
# 5                         2
# 12                        2
# 25                        1
